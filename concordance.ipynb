# %% [markdown]
# # Build your own concordance
#
# It took 500 Dominican munks to write the first concordance of the Latin bible, and it took Rabbi Mordecai Nathan 10 years to write the first concordance of the Hebrew bible. With Python, it only takes a matter of seconds to find words in a text, along with the surrounding words.
#
# Run each cell in this notebook one at a time, in order. If something in one cell doesn't work right, it might be because you have overwritten a variable, so try going back and running all the previous cells again.
#
# First run the code and check that everything works. Then, try modifying the code. Start with the first challenges, and then continue in order. Feel free to work together, and see how far you can get. The important thing is to learn, not to solve all the challenges!

# %%
# install the natural language toolkit package (nltk), which has a copy of several texts, 
#including the King James Bible

# %pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Collecting joblib (from nltk)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.2)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 8.0 MB/s eta 0:00:00
# Downloading regex-2024.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (782 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.7/782.7 kB 3.9 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Installing collected packages: regex, joblib, nltk
# Successfully installed joblib-1.4.2 nltk-3.9.1 regex-2024.9.11
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the nltk package so that it is accessible to Python, and download a collection of texts from Project Gutenberg
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /home/ucloud/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
# Create a variable called "bible" which contains the text of the King James bible.
bible = nltk.corpus.gutenberg.raw('bible-kjv.txt')

# make all characters lowercase
bible = bible.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
bible = bible.replace('\n', ' ')

# split up the text into a long list of individual words
bible = bible.split(' ')

# %%
# make a variable called "concordance", and fill it with every occurrence of the phrase "this world", and a few words preceeding and following "this world"
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        if bible[i-1] == "this":
            concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['for the children of this world are in their generation',
#  'them, the children of this world marry, and are given',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'for the prince of this world cometh, and hath nothing',
#  'because the prince of this world is judged.  16:12',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'for the fashion of this world passeth away.  7:32',
#  'whom the god of this world hath blinded the minds',
#  'chosen the poor of this world rich in faith, and',
#  'saying, the kingdoms of this world are become the kingdoms']

# %%
# let's see how many instances of the phrase "this world" were found
len(concordance)
# Out:
# 13

# %% [markdown]
# Let's try again, but this time let's just search for "world" by itself, not "this world".

# %%
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['and he hath set the world upon them.  2:9',
#  'appeared, the foundations of the world were discovered, at the',
#  'him, all the earth: the world also shall be stable,',
#  'upon the face of the world in the earth. ',
#  'and he shall judge the world in righteousness, he shall',
#  'and the foundations of the world were discovered at thy',
#  'all the ends of the world shall remember and turn',
#  'all the inhabitants of the world stand in awe of',
#  'not tell thee: for the world is mine, and the',
#  'is thine: as for the world and the fulness thereof,',
#  'he hath girded himself: the world also is stablished, that',
#  'that the lord reigneth: the world also shall be established',
#  'earth: he shall judge the world with righteousness, and the',
#  'also he hath set the world in their heart, so',
#  'and i will punish the world for their evil, and',
#  'kingdoms; 14:17 that made the world as a wilderness, and',
#  'fill the face of the world with cities.  14:22',
#  'all the kingdoms of the world upon the face of',
#  'mourneth and fadeth away, the world languisheth and fadeth away,',
#  'earth, the inhabitants of the world will learn righteousness. ',
#  'have the inhabitants of the world fallen.  26:19 thy',
#  'fill the face of the world with fruit.  27:7',
#  'not be ashamed nor confounded world without end.  45:18',
#  'since the beginning of the world men have not heard,',
#  'power, he hath established the world by his wisdom, and',
#  'power, he hath established the world by his wisdom, and',
#  'this world, neither in the world to come.  12:33',
#  ' 18:7 woe unto the world because of offences! for',
#  'be preached in all the world for a witness unto',
#  'since the beginning of the world to this time, no,',
#  'with persecutions; and in the world to come eternal life.',
#  'which have been since the world began: 1:71 that we',
#  'caesar augustus that all the world should be taxed. ',
#  'all the kingdoms of the world in a moment of',
#  'do the nations of the world seek after: and your',
#  'for the children of this world are in their generation',
#  'present time, and in the world to come life everlasting.',
#  'them, the children of this world marry, and are given',
#  'in the world, and the world was made by him,',
#  'made by him, and the world knew him not. ',
#  'not his son into the world to condemn the world;',
#  'the world; but that the world through him might be',
#  'alway ready.  7:7 the world cannot hate you; but',
#  'and i speak to the world those things which i',
#  'heareth.  9:32 since the world began was it not',
#  'ye prevail nothing? behold, the world is gone after him.',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'spirit of truth; whom the world cannot receive, because it',
#  'a little while, and the world seeth me no more;',
#  'unto you: not as the world giveth, give i unto',
#  'for the prince of this world cometh, and hath nothing',
#  ' 14:31 but that the world may know that i',
#  'another.  15:18 if the world hate you, ye know',
#  'were of the world, the world would love his own:',
#  'of the world, therefore the world hateth you.  15:20',
#  'come, he will reprove the world of sin, and of',
#  'because the prince of this world is judged.  16:12',
#  'weep and lament, but the world shall rejoice: and ye',
#  'have peace.  in the world ye shall have tribulation:',
#  'had with thee before the world was.  17:6 i',
#  'them thy word; and the world hath hated them, because',
#  'one in us: that the world may believe that thou',
#  'in one; and that the world may know that thou',
#  '17:25 o righteous father, the world hath not known thee:',
#  'i suppose that even the world itself could not contain',
#  'his holy prophets since the world began.  3:22 for',
#  'these that have turned the world upside down are come',
#  '17:24 god that made the world and all things therein,',
#  'which he will judge the world in righteousness by that',
#  'whom all asia and the world worshippeth.  19:28 and',
#  'from the creation of the world are clearly seen, being',
#  'be stopped, and all the world may become guilty before',
#  'was kept secret since the world began, 16:26 but now',
#  'the wisdom of god the world by wisdom knew not',
#  'the foolish things of the world to confound the wise;',
#  'the weak things of the world to confound the things',
#  'which god ordained before the world unto our glory: 2:8',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'the world? and if the world shall be judged by',
#  'for the fashion of this world passeth away.  7:32',
#  'eat no flesh while the world standeth, lest i make',
#  'whom the ends of the world are come.  10:12',
#  'whom the god of this world hath blinded the minds',
#  'was in christ, reconciling the world unto himself, not imputing',
#  'but the sorrow of the world worketh death.  7:11',
#  'jesus christ, by whom the world is crucified unto me,',
#  'from the beginning of the world hath been hid in',
#  'christ jesus throughout all ages, world without end. amen. ',
#  'christ jesus came into the world to save sinners; of',
#  'in christ jesus before the world began, 1:10 but is',
#  'cannot lie, promised before the world began; 1:3 but hath',
#  'not put in subjection the world to come, whereof we',
#  'and the powers of the world to come, 6:6 if',
#  'in the end of the world hath he appeared to',
#  'tormented; 11:38 (of whom the world was not worthy:) they',
#  'chosen the poor of this world rich in faith, and',
#  'tongue is a fire, a world of iniquity: so is',
#  'that the friendship of the world is enmity with god?',
#  'be a friend of the world is the enemy of',
#  'corruption that is in the world through lust.  1:5',
#  'in the flood upon the world of the ungodly; 2:6',
#  'escaped the pollutions of the world through the knowledge of',
#  'the water: 3:6 whereby the world that then was, being',
#  'world.  2:17 and the world passeth away, and the',
#  'sons of god: therefore the world knoweth us not, because',
#  'not, my brethren, if the world hate you.  3:14',
#  'of the world, and the world heareth them.  4:6',
#  'of god, and the whole world lieth in wickedness. ',
#  'saying, the kingdoms of this world are become the kingdoms',
#  'was healed: and all the world wondered after the beast.']

# %%
# let's see how many instances of just the word "world" were found
len(concordance)
# Out:
# 113

# %% [markdown]
# Now, in the cell below, modify the code to search for a different word.

# %%
# add your modified code here and run the cell...
concordance = []
for i, val in enumerate(bible):
    if val == "lord":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
concordance
# Out:
# ['in the day that the lord god made the earth',
#  'before it grew: for the lord god had not caused',
#  'ground.  2:7 and the lord god formed man of',
#  'soul.  2:8 and the lord god planted a garden',
#  'of the ground made the lord god to grow every',
#  'euphrates.  2:15 and the lord god took the man,',
#  'it.  2:16 and the lord god commanded the man,',
#  'die.  2:18 and the lord god said, it is',
#  'out of the ground the lord god formed every beast',
#  'him.  2:21 and the lord god caused a deep',
#  'and the rib, which the lord god had taken from',
#  'of the field which the lord god had made. and',
#  'heard the voice of the lord god walking in the',
#  'from the presence of the lord god amongst the trees',
#  'garden.  3:9 and the lord god called unto adam,',
#  'eat.  3:13 and the lord god said unto the',
#  'eat.  3:14 and the lord god said unto the',
#  'to his wife did the lord god make coats of',
#  'them.  3:22 and the lord god said, behold, the',
#  'for ever: 3:23 therefore the lord god sent him forth',
#  'the fat thereof. and the lord had respect unto abel',
#  'fell.  4:6 and the lord said unto cain, why',
#  'him.  4:9 and the lord said unto cain, where',
#  'me.  4:15 and the lord said unto him, therefore',
#  'on him sevenfold. and the lord set a mark upon',
#  'of the ground which the lord hath cursed.  5:30',
#  'chose.  6:3 and the lord said, my spirit shall',
#  '6:6 and it repented the lord that he had made',
#  'heart.  6:7 and the lord said, i will destroy',
#  'he.  7:1 and the lord said unto noah, come',
#  'according unto all that the lord commanded him.  7:6',
#  'had commanded him: and the lord shut him in. ',
#  'altar.  8:21 and the lord smelled a sweet savour;',
#  'a sweet savour; and the lord said in his heart,',
#  'he said, blessed be the lord god of shem; and',
#  'earth.  11:5 and the lord came down to see',
#  'builded.  11:6 and the lord said, behold, the people',
#  'speech.  11:8 so the lord scattered them abroad from',
#  'it called babel; because the lord did there confound the',
#  'and from thence did the lord scatter them abroad upon',
#  'haran.  12:1 now the lord had said unto abram,',
#  'so abram departed, as the lord had spoken unto him;',
#  'land.  12:7 and the lord appeared unto abram, and',
#  'camels.  12:17 and the lord plagued pharaoh and his',
#  'watered every where, before the lord destroyed sodom and gomorrah,',
#  'wicked and sinners before the lord exceedingly.  13:14 and',
#  'exceedingly.  13:14 and the lord said unto abram, after',
#  'things the word of the lord came unto abram in',
#  ' 15:2 and abram said, lord god, what wilt thou',
#  'behold, the word of the lord came unto him, saying,',
#  'unto him, i am the lord that brought thee out',
#  ' 15:8 and he said, lord god, whereby shall i',
#  'in the same day the lord made a covenant with',
#  'unto abram, behold now, the lord hath restrained me from',
#  'despised in her eyes: the lord judge between me and',
#  'and the angel of the lord found her by a',
#  'and the angel of the lord said unto her, return',
#  'and the angel of the lord said unto her, i',
#  'and the angel of the lord said unto her, behold,',
#  'his name ishmael; because the lord hath heard thy affliction.',
#  'called the name of the lord that spake unto her,',
#  'years old and nine, the lord appeared to abram, and',
#  'him.  18:1 and the lord appeared unto him in',
#  'shall i have pleasure, my lord being old also? ',
#  'also?  18:13 and the lord said unto abraham, wherefore',
#  'way.  18:17 and the lord said, shall i hide',
#  'justice and judgment; that the lord may bring upon abraham',
#  'him.  18:20 and the lord said, because the cry',
#  'right?  18:26 and the lord said, if i find',
#  'him, oh let not the lord be angry, and i',
#  'said, oh let not the lord be angry, and i',
#  'sake.  18:33 and the lord went his way, as',
#  'of the lord; and the lord hath sent us to',
#  'of this place; for the lord will destroy this city.',
#  'of his two daughters; the lord being merciful unto him:',
#  'zoar.  19:24 then the lord rained upon sodom and',
#  'brimstone and fire from the lord out of heaven; 19:25',
#  'children.  20:18 for the lord had fast closed up',
#  'wife.  21:1 and the lord visited sarah as he',
#  'he had said, and the lord did unto sarah as',
#  'and the angel of the lord called unto him out',
#  'in the mount of the lord it shall be seen.',
#  'and the angel of the lord called unto abraham out',
#  'stricken in age: and the lord had blessed abraham in',
#  'thither again.  24:7 the lord god of heaven, which',
#  '24:12 and he said o lord god of my master',
#  'peace, to wit whether the lord had made his journey',
#  'he said, blessed be the lord god of my master',
#  'being in the way, the lord led me to the',
#  'servant.  24:35 and the lord hath blessed my master',
#  'the well, and said, o lord god of my master',
#  'be the woman whom the lord hath appointed out for',
#  'the lord, and blessed the lord god of my master',
#  "master's son's wife, as the lord hath spoken.  24:52",
#  'hinder me not, seeing the lord hath prospered my way;',
#  '25:21 and isaac intreated the lord for his wife, because',
#  'she was barren: and the lord was intreated of him,',
#  'lord.  25:23 and the lord said unto her, two',
#  'gerar.  26:2 and the lord appeared unto him, and',
#  'year an hundredfold: and the lord blessed him.  26:13',
#  'he said, for now the lord hath made room for',
#  'beersheba.  26:24 and the lord appeared unto him the',
#  'lips?  6:13 and the lord spake unto moses and',
#  'and moses, to whom the lord said, bring out the',
#  'on the day when the lord spake unto moses in',
#  'of egypt, 6:29 that the lord spake unto moses, saying,',
#  'me?  7:1 and the lord said unto moses, see,',
#  'and aaron did as the lord commanded them, so did',
#  'pharaoh.  7:8 and the lord spake unto moses and',
#  'they did so as the lord had commanded: and aaron',
#  'not unto them; as the lord had said.  7:14',
#  "said.  7:14 and the lord said unto moses, pharaoh's",
#  'shalt say unto him, the lord god of the hebrews',
#  'river.  7:19 and the lord spake unto moses, say',
#  'aaron did so, as the lord commanded; and he lifted',
#  'hearken unto them; as the lord had said.  7:23',
#  'were fulfilled, after that the lord had smitten the river.',
#  'river.  8:1 and the lord spake unto moses, go',
#  'servants.  8:5 and the lord spake unto moses, say',
#  'is none like unto the lord our god.  8:11',
#  'and moses cried unto the lord because of the frogs',
#  'pharaoh.  8:13 and the lord did according to the',
#  'not unto them; as the lord had said.  8:16',
#  'said.  8:16 and the lord said unto moses, say',
#  'not unto them; as the lord had said.  8:20',
#  'said.  8:20 and the lord said unto moses, rise',
#  'know that i am the lord in the midst of',
#  'be.  8:24 and the lord did so; and there',
#  'of the egyptians to the lord our god: lo, shall',
#  'wilderness, and sacrifice to the lord our god, as he',
#  'ye may sacrifice to the lord your god in the',
#  'and i will intreat the lord that the swarms of',
#  'lord.  8:31 and the lord did according to the',
#  'go.  9:1 then the lord said unto moses, go',
#  'tell him, thus saith the lord god of the hebrews,',
#  'behold, the hand of the lord is upon thy cattle',
#  'murrain.  9:4 and the lord shall sever between the',
#  'israel.  9:5 and the lord appointed a set time,',
#  'time, saying, to morrow the lord shall do this thing',
#  'land.  9:6 and the lord did that thing on',
#  'go.  9:8 and the lord said unto moses and',
#  'egyptians.  9:12 and the lord hardened the heart of',
#  'not unto them; as the lord had spoken unto moses.',
#  'moses.  9:13 and the lord said unto moses, rise',
#  'unto him, thus saith the lord god of the hebrews,',
#  'feared the word of the lord among the servants of',
#  'not the word of the lord left his servants and',
#  'field.  9:22 and the lord said unto moses, stretch',
#  'rod toward heaven: and the lord sent thunder and hail,',
#  'upon the ground; and the lord rained hail upon the',
#  'have sinned this time: the lord is righteous, and i',
#  'wicked.  9:28 intreat the lord (for it is enough)',
#  'will not yet fear the lord god.  9:31 and',
#  'of israel go; as the lord had spoken by moses.',
#  'moses.  10:1 and the lord said unto moses, go',
#  'unto him, thus saith the lord god of the hebrews,',
#  'that they may serve the lord their god: knowest thou',
#  'unto them, go, serve the lord your god: but who',
#  'said unto them, let the lord be so with you,',
#  'presence.  10:12 and the lord said unto moses, stretch',
#  'land of egypt, and the lord brought an east wind',
#  'i have sinned against the lord your god, and against',
#  'this once, and intreat the lord your god, that he',
#  'lord.  10:19 and the lord turned a mighty strong',
#  "egypt.  10:20 but the lord hardened pharaoh's heart, so",
#  'go.  10:21 and the lord said unto moses, stretch',
#  'we may sacrifice unto the lord our god.  10:26',
#  'we take to serve the lord our god; and we',
#  "thither.  10:27 but the lord hardened pharaoh's heart, and",
#  'more.  11:1 and the lord said unto moses, yet',
#  'gold.  11:3 and the lord gave the people favour',
#  'may know how that the lord doth put a difference',
#  'anger.  11:9 and the lord said unto moses, pharaoh',
#  "wonders before pharaoh: and the lord hardened pharaoh's heart, so",
#  'land.  12:1 and the lord spake unto moses and',
#  'it a feast to the lord throughout your generations; ye',
#  'morning.  12:23 for the lord will pass through to',
#  'the two side posts, the lord will pass over the',
#  'to the land which the lord will give you, according',
#  'away, and did as the lord had commanded moses and',
#  'pass, that at midnight the lord smote all the firstborn',
#  'and raiment: 12:36 and the lord gave the people favour',
#  'all the hosts of the lord went out from the',
#  'be much observed unto the lord for bringing them out',
#  'is that night of the lord to be observed of',
#  'generations.  12:43 and the lord said unto moses and',
#  'children of israel; as the lord commanded moses and aaron,',
#  'the selfsame day, that the lord did bring the children',
#  'armies.  13:1 and the lord spake unto moses, saying,',
#  'by strength of hand the lord brought you out from',
#  'it shall be when the lord shall bring thee into',
#  'because of that which the lord did unto me when',
#  'a strong hand hath the lord brought thee out of',
#  'it shall be when the lord shall bring thee into',
#  'shalt set apart unto the lord all that openeth the',
#  'by strength of hand the lord brought us out from',
#  'let us go, that the lord slew all the firstborn',
#  'therefore i sacrifice to the lord all that openeth the',
#  'by strength of hand the lord brought us forth out',
#  'wilderness.  13:21 and the lord went before them by',
#  'people.  14:1 and the lord spake unto moses, saying,',
#  'them.  14:8 and the lord hardened the heart of',
#  'for ever.  14:14 the lord shall fight for you,',
#  'peace.  14:15 and the lord said unto moses, wherefore',
#  'over the sea; and the lord caused the sea to',
#  'in the morning watch the lord looked unto the host',
#  'face of israel; for the lord fighteth for them against',
#  'egyptians.  14:26 and the lord said unto moses, stretch',
#  'fled against it; and the lord overthrew the egyptians in',
#  'left.  14:30 thus the lord saved israel that day',
#  'that great work which the lord did upon the egyptians:',
#  'the sea.  15:2 the lord is my strength and',
#  'exalt him.  15:3 the lord is a man of',
#  'a man of war: the lord is his name. ',
#  'have established.  15:18 the lord shall reign for ever',
#  'into the sea, and the lord brought again the waters',
#  'unto the lord; and the lord shewed him a tree,',
#  'to the voice of the lord thy god, and wilt',
#  'egyptians: for i am the lord that healeth thee. ',
#  'by the hand of the lord in the land of',
#  ' 16:4 then said the lord unto moses, behold, i',
#  'ye shall know that the lord hath brought you out',
#  'this shall be, when the lord shall give you in',
#  'the full; for that the lord heareth your murmurings which',
#  'behold, the glory of the lord appeared in the cloud.',
#  'cloud.  16:11 and the lord spake unto moses, saying,',
#  'know that i am the lord your god.  16:13',
#  'is the bread which the lord hath given you to',
#  'is the thing which the lord hath commanded, gather of',
#  'this is that which the lord hath said, to morrow',
#  'none.  16:28 and the lord said unto moses, how',
#  '16:29 see, for that the lord hath given you the',
#  'is the thing which the lord commandeth, fill an omer',
#  'generations.  16:34 as the lord commanded moses, so aaron',
#  'me.  17:5 and the lord said unto moses, go',
#  'the lord, saying, is the lord among us, or not?',
#  'sword.  17:14 and the lord said unto moses, write',
#  'for he said, because the lord hath sworn that the',
#  'lord hath sworn that the lord will have war with',
#  'his people, and that the lord had brought israel out',
#  'in law all that the lord had done unto pharaoh',
#  'the way, and how the lord delivered them.  18:9',
#  'all the goodness which the lord had done to israel,',
#  'now i know that the lord is greater than all',
#  'up unto god, and the lord called unto him out',
#  'all these words which the lord commanded him.  19:8',
#  'and said, all that the lord hath spoken we will',
#  'lord.  19:9 and the lord said unto moses, lo,',
#  'lord.  19:10 and the lord said unto moses, go',
#  'for the third day the lord will come down in',
#  'on a smoke, because the lord descended upon it in',
#  'voice.  19:20 and the lord came down upon mount',
#  'of the mount: and the lord called moses up to',
#  'up.  19:21 and the lord said unto moses, go',
#  'they break through unto the lord to gaze, and many',
#  'lord, sanctify themselves, lest the lord break forth upon them.',
#  'it.  19:24 and the lord said unto him, away,',
#  'saying, 20:2 i am the lord thy god, which have',
#  'serve them: for i the lord thy god am a',
#  'take the name of the lord thy god in vain;',
#  'god in vain; for the lord will not hold him',
#  'is the sabbath of the lord thy god: in it',
#  'for in six days the lord made heaven and earth,',
#  'the seventh day: wherefore the lord blessed the sabbath day,',
#  'upon the land which the lord thy god giveth thee.',
#  'was.  20:22 and the lord said unto moses, thus',
#  'shall an oath of the lord be between them both,',
#  'any god, save unto the lord only, he shall be',
#  'males shall appear before the lord god.  23:18 thou',
#  'into the house of the lord thy god. thou shalt',
#  'and ye shall serve the lord your god, and he',
#  'all the words which the lord hath said will we',
#  'they said, all that the lord hath said will we',
#  'of the covenant, which the lord hath made with you',
#  'drink.  24:12 and the lord said unto moses, come',
#  'and the glory of the lord abode upon mount sinai,',
#  'of the glory of the lord was like devouring fire',
#  'nights.  25:1 and the lord spake unto moses, saying,',
#  'bear their names before the lord upon his two shoulders',
#  'for a memorial before the lord continually.  28:30 and',
#  'upon his heart before the lord continually.  28:31 and',
#  'know that i am the lord their god, that brought',
#  'among them: i am the lord their god.  30:1',
#  'a perpetual incense before the lord throughout your generations. ',
#  'lord.  30:11 and the lord spake unto moses, saying,',
#  'souls.  30:17 and the lord spake unto moses, saying,',
#  'generations.  30:22 moreover the lord spake unto moses, saying,',
#  'people.  30:34 and the lord said unto moses, take',
#  'people.  31:1 and the lord spake unto moses, saying,',
#  'do.  31:12 and the lord spake unto moses, saying,',
#  'know that i am the lord that doth sanctify you.',
#  'for in six days the lord made heaven and earth,',
#  'play.  32:7 and the lord said unto moses, go,',
#  'egypt.  32:9 and the lord said unto moses, i',
#  '32:11 and moses besought the lord his god, and said,',
#  'ever.  32:14 and the lord repented of the evil',
#  'not the anger of my lord wax hot: thou knowest',
#  'unto them, thus saith the lord god of israel, put',
#  'written.  32:33 and the lord said unto moses, whosoever',
#  'them.  32:35 and the lord plagued the people, because',
#  'made.  33:1 and the lord said unto moses, depart,',
#  'ornaments.  33:5 for the lord had said unto moses,',
#  'every one which sought the lord went out unto the',
#  'of the tabernacle, and the lord talked with moses. ',
#  'door.  33:11 and the lord spake unto moses face',
#  'earth.  33:17 and the lord said unto moses, i',
#  'proclaim the name of the lord before thee; and will',
#  'live.  33:21 and the lord said, behold, there is',
#  'seen.  34:1 and the lord said unto moses, hew',
#  'unto mount sinai, as the lord had commanded him, and',
#  'stone.  34:5 and the lord descended in the cloud,',
#  'lord.  34:6 and the lord passed by before him,',
#  'and proclaimed, the lord, the lord god, merciful and gracious,',
#  'your menchildren appear before the lord god, the god of',
#  'up to appear before the lord thy god thrice in',
#  'unto the house of the lord thy god. thou shalt',
#  'milk.  34:27 and the lord said unto moses, write',
#  'he was there with the lord forty days and forty',
#  'in commandment all that the lord had spoken with him',
#  'moses went in before the lord to speak with him,',
#  'are the words which the lord hath commanded, that ye',
#  'is the thing which the lord commanded, saying, 35:5 take',
#  'and make all that the lord hath commanded; 35:11 the',
#  'manner of work, which the lord had commanded to be',
#  'children of israel, see, the lord hath called by name',
#  'hearted man, in whom the lord put wisdom and understanding',
#  'according to all that the lord had commanded.  36:2',
#  'man, in whose heart the lord had put wisdom, even',
#  'of the work, which the lord commanded to make. ',
#  'judah, made all that the lord commanded moses.  38:23',
#  'garments for aaron; as the lord commanded moses.  39:2',
#  'fine twined linen; as the lord commanded moses.  39:6',
#  'children of israel; as the lord commanded moses.  39:8',
#  'from the ephod; as the lord commanded moses.  39:22',
#  'to minister in; as the lord commanded moses.  39:27',
#  'scarlet, of needlework; as the lord commanded moses.  39:30',
#  'upon the mitre; as the lord commanded moses.  39:32',
#  'according to all that the lord commanded moses, so did',
#  'according to all that the lord commanded moses, so the',
#  'had done it as the lord had commanded, even so',
#  'them.  40:1 and the lord spake unto moses, saying,',
#  'according to all that the lord commanded him, so did',
#  'above upon it; as the lord commanded moses.  40:20',
#  'of the testimony; as the lord commanded moses.  40:22',
#  'before the lord; as the lord had commanded moses. ',
#  'before the lord; as the lord commanded moses.  40:26',
#  'sweet incense thereon; as the lord commanded moses.  40:28',
#  'the meat offering; as the lord commanded moses.  40:30',
#  'altar, they washed; as the lord commanded moses.  40:33',
#  'and the glory of the lord filled the tabernacle. ',
#  'and the glory of the lord filled the tabernacle. ',
#  'for the cloud of the lord was upon the tabernacle',
#  '  1:1 and the lord called unto moses, and',
#  'for his offering to the lord be of fowls, then',
#  'of the offerings of the lord made by fire. ',
#  'of the offerings of the lord made by fire. ',
#  'in any offering of the lord made by fire. ',
#  'of peace offering unto the lord be of the flock;',
#  'blood.  4:1 and the lord spake unto moses, saying,',
#  'of the commandments of the lord concerning things which ought',
#  'bullock without blemish unto the lord for a sin offering.',
#  'of the commandments of the lord concerning things which should',
#  'of the commandments of the lord his god concerning things',
#  'of the commandments of the lord concerning things which ought',
#  'his trespass offering unto the lord for his sin which',
#  'offering.  5:14 and the lord spake unto moses, saying,',
#  'for his trespass unto the lord a ram without blemish',
#  'lord.  6:1 and the lord spake unto moses, saying,',
#  'therein.  6:8 and the lord spake unto moses, saying,',
#  'concerning the offerings of the lord made by fire: every',
#  'holy.  6:19 and the lord spake unto moses, saying,',
#  'they shall offer unto the lord in the day when',
#  'eaten.  6:24 and the lord spake unto moses, saying,',
#  'people.  7:22 and the lord spake unto moses, saying,',
#  'people.  7:28 and the lord spake unto moses, saying,',
#  'his peace offerings unto the lord shall bring his oblation',
#  'bring his oblation unto the lord of the sacrifice of',
#  'bring the offerings of the lord made by fire, the',
#  'of the offerings of the lord made by fire, in',
#  "them to minister unto the lord in the priest's office;",
#  "priest's office; 7:36 which the lord commanded to be given",
#  'peace offerings; 7:38 which the lord commanded moses in mount',
#  'sinai.  8:1 and the lord spake unto moses, saying,',
#  'and moses did as the lord commanded him; and the',
#  'is the thing which the lord commanded to be done.',
#  'the holy crown; as the lord commanded moses.  8:10',
#  'bonnets upon them; as the lord commanded moses.  8:14',
#  'without the camp; as the lord commanded moses.  8:18',
#  'unto the lord; as the lord commanded moses.  8:22',
#  "was moses' part; as the lord commanded moses.  8:30",
#  'done this day, so the lord hath commanded to do,',
#  'did all things which the lord commanded by the hand',
#  'oil: for to day the lord will appear unto you.',
#  'is the thing which the lord commanded that ye should',
#  'and the glory of the lord shall appear unto you.',
#  'atonement for them; as the lord commanded.  9:8 aaron',
#  'upon the altar; as the lord commanded moses.  9:11',
#  'and the glory of the lord appeared unto all the',
#  'this is it that the lord spake, saying, i will',
#  'bewail the burning which the lord hath kindled.  10:7',
#  'the anointing oil of the lord is upon you. and',
#  'moses.  10:8 and the lord spake unto aaron, saying,',
#  'all the statutes which the lord hath spoken unto them',
#  'of the offerings of the lord made by fire, and',
#  'of the sacrifices of the lord made by fire: for',
#  'statute for ever; as the lord hath commanded.  10:16',
#  'content.  11:1 and the lord spake unto moses and',
#  '11:44 for i am the lord your god: ye shall',
#  '11:45 for i am the lord that bringeth you up',
#  'eaten.  12:1 and the lord spake unto moses, saying,',
#  'clean.  13:1 and the lord spake unto moses and',
#  'unclean.  14:1 and the lord spake unto moses, saying,',
#  'cleansing.  14:33 and the lord spake unto moses and',
#  'leprosy.  15:1 and the lord spake unto moses and',
#  'pigeons, and come before the lord unto the door of',
#  'atonement for him before the lord for his issue. ',
#  'atonement for her before the lord for the issue of',
#  'unclean.  16:1 and the lord spake unto moses after',
#  'and died; 16:2 and the lord said unto moses, speak',
#  'and present them before the lord at the door of',
#  'and he did as the lord commanded moses.  17:1',
#  'moses.  17:1 and the lord spake unto moses, saying,',
#  'is the thing which the lord hath commanded, saying, 17:3',
#  'offer an offering unto the lord before the tabernacle of',
#  'upon the altar of the lord at the door of',
#  'iniquity.  18:1 and the lord spake unto moses, saying,',
#  'unto them, i am the lord your god.  18:3',
#  'walk therein: i am the lord your god.  18:5',
#  'yourselves therein: i am the lord your god.  19:1',
#  'god.  19:1 and the lord spake unto moses, saying,',
#  'be holy: for i the lord your god am holy.',
#  'my sabbaths: i am the lord your god.  19:4',
#  'molten gods: i am the lord your god.  19:5',
#  'and stranger: i am the lord your god.  19:11',
#  'the trespass offering before the lord for his sin which',
#  'according to all that the lord commanded moses, so did',
#  'they.  2:1 and the lord spake unto moses and',
#  'children of israel; as the lord commanded moses.  2:34',
#  'according to all that the lord commanded moses: so they',
#  'in the day that the lord spake with moses in',
#  'father.  3:5 and the lord spake unto moses, saying,',
#  'death.  3:11 and the lord spake unto moses, saying,',
#  'lord.  3:14 and the lord spake unto moses in',
#  'thousand.  3:40 and the lord said unto moses, number',
#  'and moses numbered, as the lord commanded him, all the',
#  'thirteen.  3:44 and the lord spake unto moses, saying,',
#  'of the lord, as the lord commanded moses.  4:1',
#  'moses.  4:1 and the lord spake unto moses and',
#  'thereof.  4:17 and the lord spake unto moses and',
#  'die.  4:21 and the lord spake unto moses, saying,',
#  'to the commandment of the lord by the hand of',
#  'to the word of the lord by the hand of',
#  'to the commandment of the lord they were numbered by',
#  'numbered of him, as the lord commanded moses.  5:1',
#  'moses.  5:1 and the lord spake unto moses, saying,',
#  'without the camp: as the lord spake unto moses, so',
#  'israel.  5:5 and the lord spake unto moses, saying,',
#  'his.  5:11 and the lord spake unto moses, saying,',
#  'say unto the woman, the lord make thee a curse',
#  'among thy people, when the lord doth make thy thigh',
#  'iniquity.  6:1 and the lord spake unto moses, saying,',
#  'he separateth himself unto the lord he shall come at',
#  'he shall consecrate unto the lord the days of his',
#  'of his offering unto the lord for his separation, beside',
#  'separation.  6:22 and the lord spake unto moses, saying,',
#  'saying unto them, 6:24 the lord bless thee, and keep',
#  'and keep thee: 6:25 the lord make his face shine',
#  'gracious unto thee: 6:26 the lord lift up his countenance',
#  'tabernacle.  7:4 and the lord spake unto moses, saying,',
#  'altar.  7:11 and the lord said unto moses, they',
#  'him.  8:1 and the lord spake unto moses, saying,',
#  'against the candlestick, as the lord commanded moses.  8:4',
#  'unto the pattern which the lord had shewed moses, so',
#  'candlestick.  8:5 and the lord spake unto moses, saying,',
#  'offer the levites before the lord for an offering of',
#  'according unto all that the lord commanded moses concerning the',
#  'before his sons: as the lord had commanded moses concerning',
#  'them.  8:23 and the lord spake unto moses, saying,',
#  'charge.  9:1 and the lord spake unto moses in',
#  'according to all that the lord commanded moses, so did',
#  'offer an offering of the lord in his appointed season',
#  'i will hear what the lord will command concerning you.',
#  'you.  9:9 and the lord spake unto moses, saying,',
#  'not the offering of the lord in his appointed season,',
#  'at the commandment of the lord the children of israel',
#  'at the commandment of the lord they pitched: as long',
#  'to the commandment of the lord they abode in their',
#  'to the commandment of the lord they journeyed.  9:21',
#  'at the commandment of the lord they rested in the',
#  'at the commandment of the lord they journeyed: they kept',
#  'at the commandment of the lord by the hand of',
#  'moses.  10:1 and the lord spake unto moses, saying,',
#  'shall be remembered before the lord your god, and ye',
#  'your god: i am the lord your god.  10:11',
#  'to the commandment of the lord by the hand of',
#  'the place of which the lord said, i will give',
#  'do thee good: for the lord hath spoken good concerning',
#  'be, that what goodness the lord shall do unto us,',
#  "from the mount of the lord three days' journey: and",
#  'of the covenant of the lord went before them in',
#  'and the cloud of the lord was upon them by',
#  'displeased the lord: and the lord heard it; and his',
#  'and the fire of the lord burnt among them, and',
#  'because the fire of the lord burnt among them. ',
#  'and the anger of the lord was kindled greatly; moses',
#  'wretchedness.  11:16 and the lord said unto moses, gather',
#  'us in egypt: therefore the lord will give you flesh,',
#  'that ye have despised the lord which is among you,',
#  'them?  11:23 and the lord said unto moses, is',
#  'tabernacle.  11:25 and the lord came down in a',
#  'men, answered and said, my lord moses, forbid them. ',
#  'were prophets, and that the lord would put his spirit',
#  'chewed, the wrath of the lord was kindled against the',
#  'against the people, and the lord smote the people with',
#  'and they said, hath the lord indeed spoken only by',
#  'also by us? and the lord heard it.  12:3',
#  'earth.)  12:4 and the lord spake suddenly unto moses,',
#  'out.  12:5 and the lord came down in the',
#  'prophet among you, i the lord will make myself known',
#  'and the similitude of the lord shall he behold: wherefore',
#  'and the anger of the lord was kindled against them;',
#  'thee.  12:14 and the lord said unto moses, if',
#  'paran.  13:1 and the lord spake unto moses, saying,',
#  'by the commandment of the lord sent them from the',
#  '14:3 and wherefore hath the lord brought us unto this',
#  'land.  14:8 if the lord delight in us, then',
#  'departed from them, and the lord is with us: fear',
#  'and the glory of the lord appeared in the tabernacle',
#  'israel.  14:11 and the lord said unto moses, how',
#  'they have heard that thou lord art among this people,',
#  'among this people, that thou lord art seen face to',
#  'speak, saying, 14:16 because the lord was not able to',
#  'let the power of my lord be great, according as',
#  'hast spoken, saying, 14:18 the lord is longsuffering, and of',
#  'now.  14:20 and the lord said, i have pardoned',
#  'sea.  14:26 and the lord spake unto moses and',
#  'promise.  14:35 i the lord have said, i will',
#  'unto the place which the lord hath promised: for we',
#  'go not up, for the lord is not among you;',
#  'from the lord, therefore the lord will not be with',
#  'hormah.  15:1 and the lord spake unto moses, saying,',
#  'offereth his offering unto the lord bring a meat offering',
#  'you.  15:17 and the lord spake unto moses, saying,',
#  'ye shall give unto the lord an heave offering in',
#  'all these commandments, which the lord hath spoken unto moses,',
#  '15:23 even all that the lord hath commanded you by',
#  'from the day that the lord commanded moses, and henceforward',
#  'him.  15:35 and the lord said unto moses, the',
#  'and he died; as the lord commanded moses.  15:37',
#  'moses.  15:37 and the lord spake unto moses, saying,',
#  ' 15:41 i am the lord your god, which brought',
#  'your god: i am the lord your god.  16:1',
#  'one of them, and the lord is among them: wherefore',
#  'saying, even to morrow the lord will shew who are',
#  'incense in them before the lord to morrow: and it',
#  'that the man whom the lord doth choose, he shall',
#  'and bring ye before the lord every man his censer,',
#  'and the glory of the lord appeared unto all the',
#  'congregation.  16:20 and the lord spake unto moses and',
#  'congregation?  16:23 and the lord spake unto moses, saying,',
#  'ye shall know that the lord hath sent me to',
#  'of all men; then the lord hath not sent me.',
#  ' 16:30 but if the lord make a new thing,',
#  'incense.  16:36 and the lord spake unto moses, saying,',
#  'as his company: as the lord said to him by',
#  'and the glory of the lord appeared.  16:43 and',
#  'congregation.  16:44 and the lord spake unto moses, saying,',
#  'stayed.  17:1 and the lord spake unto moses, saying,',
#  'up the rods before the lord in the tabernacle of',
#  'the rods from before the lord unto all the children',
#  'rod.  17:10 and the lord said unto moses, bring',
#  'moses did so: as the lord commanded him, so did',
#  'unto the tabernacle of the lord shall die: shall we',
#  'dying?  18:1 and the lord said unto aaron, thou',
#  'death.  18:8 and the lord spake unto aaron, behold,',
#  'salt for ever before the lord unto thee and to',
#  'thee.  18:20 and the lord spake unto aaron, thou',
#  'inheritance.  18:25 and the lord spake unto moses, saying,',
#  'an heave offering unto the lord of all your tithes,',
#  'die.  19:1 and the lord spake unto moses and',
#  'of the law which the lord hath commanded, saying, speak',
#  'up the congregation of the lord into this wilderness, that',
#  'and the glory of the lord appeared unto them. ',
#  'them.  20:7 and the lord spake unto moses, saying,',
#  'also.  20:12 and the lord spake unto moses and',
#  'hor.  20:23 and the lord spake unto moses and',
#  'and moses did as the lord commanded: and they went',
#  'cities.  21:3 and the lord hearkened to the voice',
#  'bread.  21:6 and the lord sent fiery serpents among',
#  'people.  21:8 and the lord said unto moses, make',
#  'is the well whereof the lord spake unto moses, gather',
#  'edrei.  21:34 and the lord said unto moses, fear',
#  'you word again, as the lord shall speak unto me:',
#  'into your land: for the lord refuseth to give me',
#  'beyond the word of the lord my god, to do',
#  'i may know what the lord will say unto me',
#  'and the angel of the lord stood in the way',
#  'saw the angel of the lord standing in the way,',
#  'but the angel of the lord stood in a path',
#  'and the angel of the lord went further, and stood',
#  'staff.  22:28 and the lord opened the mouth of',
#  'nay.  22:31 then the lord opened the eyes of',
#  'saw the angel of the lord standing in the way,',
#  'and the angel of the lord said unto him, wherefore',
#  'and the angel of the lord said unto balaam, go',
#  'i will go: peradventure the lord will come to meet',
#  'ram.  23:5 and the lord put a word in',
#  'shall i defy, whom the lord hath not defied? ',
#  'to speak that which the lord hath put in my',
#  'offering, while i meet the lord yonder.  23:16 and',
#  'yonder.  23:16 and the lord met balaam, and put',
#  'unto him, what hath the lord spoken?  23:18 and',
#  'seen perverseness in israel: the lord his god is with',
#  'thee, saying, all that the lord speaketh, that i must',
#  'saw that it pleased the lord to bless israel, he',
#  'of lign aloes which the lord hath planted, and as',
#  'great honour; but, lo, the lord hath kept thee back',
#  'own mind; but what the lord saith, that will i',
#  'and the anger of the lord was kindled against israel.',
#  'israel.  25:4 and the lord said unto moses, take',
#  'hang them up before the lord against the sun, that',
#  'the fierce anger of the lord may be turned away',
#  'thousand.  25:10 and the lord spake unto moses, saying,',
#  'midian.  25:16 and the lord spake unto moses, saying,',
#  'after the plague, that the lord spake unto moses and',
#  'old and upward; as the lord commanded moses and the',
#  'thirty.  26:52 and the lord spake unto moses, saying,',
#  'sinai.  26:65 for the lord had said of them,',
#  'gathered themselves together against the lord in the company of',
#  'lord.  27:6 and the lord spake unto moses, saying,',
#  'statute of judgment, as the lord commanded moses.  27:12',
#  'moses.  27:12 and the lord said unto moses, get',
#  'that the congregation of the lord be not as sheep',
#  'shepherd.  27:18 and the lord said unto moses, take',
#  'and moses did as the lord commanded him: and he',
#  'him a charge, as the lord commanded by the hand',
#  'moses.  28:1 and the lord spake unto moses, saying,',
#  'to be poured unto the lord for a drink offering.',
#  'a sin offering unto the lord shall be offered, beside',
#  'a burnt offering unto the lord for a sweet savour;',
#  'keep a feast unto the lord seven days: 29:13 and',
#  'ye shall do unto the lord in your set feasts,',
#  'according to all that the lord commanded moses.  30:1',
#  'is the thing which the lord hath commanded.  30:2',
#  'soul, shall stand: and the lord shall forgive her, because',
#  'of none effect: and the lord shall forgive her. ',
#  'made them void; and the lord shall forgive her. ',
#  'are the statutes, which the lord commanded moses, between a',
#  'house.  31:1 and the lord spake unto moses, saying,',
#  'the midianites, and avenge the lord of midian.  31:4',
#  'against the midianites, as the lord commanded moses; and they',
#  'to commit trespass against the lord in the matter of',
#  'of the law which the lord commanded moses; 31:22 only',
#  'camp.  31:25 and the lord spake unto moses, saying,',
#  'levy a tribute unto the lord of the men of',
#  'the priest did as the lord commanded moses.  31:32',
#  'eleazar the priest, as the lord commanded moses.  31:42',
#  'of the lord; as the lord commanded moses.  31:48',
#  'even the country which the lord smote before the congregation',
#  'into the land which the lord hath given them? ',
#  'into the land which the lord had given them. ',
#  'the fierce anger of the lord toward israel.  32:15',
#  'will go armed before the lord to war, 32:21 and',
#  'servants will do as my lord commandeth.  32:26 our',
#  'armed for war, before the lord to battle, as my',
#  'lord to battle, as my lord saith.  32:28 so',
#  'reuben answered, saying, as the lord hath said unto thy',
#  'pass over armed before the lord into the land of',
#  'all their firstborn, which the lord had smitten among them:',
#  'upon their gods also the lord executed judgments.  33:5',
#  'moab.  33:50 and the lord spake unto moses in',
#  'them.  34:1 and the lord spake unto moses, saying,',
#  'inherit by lot, which the lord commanded to give unto',
#  'sunrising.  34:16 and the lord spake unto moses, saying,',
#  'these are they whom the lord commanded to divide the',
#  'canaan.  35:1 and the lord spake unto moses in',
#  'inheriteth.  35:9 and the lord spake unto moses, saying,',
#  'i dwell: for i the lord dwell among the children',
#  '36:2 and they said, the lord commanded my lord to',
#  'said, the lord commanded my lord to give the land',
#  'children of israel: and my lord was commanded by the',
#  'lord was commanded by the lord to give the inheritance',
#  'is the thing which the lord doth command concerning the',
#  ' 36:10 even as the lord commanded moses, so did',
#  'and the judgments, which the lord commanded by the hand',
#  'according unto all that the lord had given him in',
#  'this law, saying, 1:6 the lord our god spake unto',
#  'possess the land which the lord sware unto your fathers,',
#  'you myself alone: 1:10 the lord your god hath multiplied',
#  'for multitude.  1:11 (the lord god of your fathers',
#  'of the amorites, as the lord our god commanded us;',
#  'of the amorites, which the lord our god doth give',
#  'us.  1:21 behold, the lord thy god hath set',
#  'and possess it, as the lord god of thy fathers',
#  'a good land which the lord our god doth give',
#  'against the commandment of the lord your god: 1:27 and',
#  'tents, and said, because the lord hated us, he hath',
#  'of them.  1:30 the lord your god which goeth',
#  'hast seen how that the lord thy god bare thee,',
#  'ye did not believe the lord your god, 1:33 who',
#  'day.  1:34 and the lord heard the voice of',
#  'destroy them quickly, as the lord hath said unto thee.',
#  'thine heart, after that the lord thy god hath cast',
#  'saying, for my righteousness the lord hath brought me in',
#  'wickedness of these nations the lord doth drive them out',
#  'wickedness of these nations the lord thy god doth drive',
#  'perform the word which the lord sware unto thy fathers,',
#  '9:6 understand therefore, that the lord thy god giveth thee',
#  'not, how thou provokedst the lord thy god to wrath',
#  'in horeb ye provoked the lord to wrath, so that',
#  'to wrath, so that the lord was angry with you',
#  'of the covenant which the lord made with you, then',
#  'drink water: 9:10 and the lord delivered unto me two',
#  'all the words, which the lord spake with you in',
#  'and forty nights, that the lord gave me the two',
#  'covenant.  9:12 and the lord said unto me, arise,',
#  'image.  9:13 furthermore the lord spake unto me, saying,',
#  'ye had sinned against the lord your god, and had',
#  'of the way which the lord had commanded you. ',
#  'and hot displeasure, wherewith the lord was wroth against you',
#  'to destroy you. but the lord hearkened unto me at',
#  'also.  9:20 and the lord was very angry with',
#  'at kibrothhattaavah, ye provoked the lord to wrath.  9:23',
#  ' 9:23 likewise when the lord sent you from kadeshbarnea,',
#  'against the commandment of the lord your god, and ye',
#  'have been rebellious against the lord from the day that',
#  'i fell down before the lord forty days and forty',
#  ...]

# %%
len(concordance)
# Out:
# 4739

# %% [markdown]
# The nltk package has the full text of several other classic books. You can see what they are called by running the command in the cell below:

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# ## Your turn!
#
# Here are a some more things you can try. In each case, I have given you a little bit of starter code to get you going, but the cells will not run without some additional code from you.

# %% [markdown]
# ## Challenge 1: build your own concordance
#
# Pick a different book and a different word, or pair of words. Copy and paste from the code above to write some Python code that searches the book of your choice for the word or pair of words of your choice. Put this code in the cell below. By the way, some of the texts use the characters "\r" for "carriage return" instead of "\n" for "newline". You can remove these the same way that you remove the "\n" characters.

# %%
# add your code to search for a word or pair of words in a different book here
hamlet = nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt')

# make all characters lowercase
hamlet = hamlet.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
hamlet = hamlet.replace('\n', ' ')

# split up the text into a long list of individual words
hamlet = hamlet.split()

# %%
concordance = []
for i, val in enumerate(hamlet):
    if val == "life":
        concordance.append(str(' '.join(hamlet[i-5:i+5])))

# %%
concordance
# Out:
# ['thou hast vp-hoorded in thy life extorted treasure in the',
#  'i doe not set my life at a pins fee;',
#  'withall, except my life, my life polon. fare you well',
#  'mans memorie, may out-liue his life halfe a yeare: but',
#  'rosin. the single and peculiar life is bound with all',
#  'alarme, your bedded haire, like life in excrements, start vp,',
#  'of life: i haue no life to breath what thou',
#  'noble father slaine, pursued my life laer. it well appeares.',
#  'a norman laer. vpon my life lamound kin. the very',
#  'death, shortens not his owne life other. but is this',
#  "had it th' abilitie of life to thanke you: he"]

# %% [markdown]
# ## Challenge 2: compare lengths of books
#
# We can use the command `len` to find how many items there are in a list. E.g., to find the number of words in the list called `bible`, above, we can write: `len(bible)`.
#
# Use the starter code below to find out which book in the books included in `nltk` has the most words.

# %%
# solution 1: print all the titles and numbers of words
# starter code:

books = nltk.corpus.gutenberg.fileids()

for title in books:
    book = nltk.corpus.gutenberg.raw(title)
    print(title, len(book))
# Out:
# austen-emma.txt 887071
# austen-persuasion.txt 466292
# austen-sense.txt 673022
# bible-kjv.txt 4332554
# blake-poems.txt 38153
# bryant-stories.txt 249439
# burgess-busterbrown.txt 84663
# carroll-alice.txt 144395
# chesterton-ball.txt 457450
# chesterton-brown.txt 406629
# chesterton-thursday.txt 320525
# edgeworth-parents.txt 935158
# melville-moby_dick.txt 1242990
# milton-paradise.txt 468220
# shakespeare-caesar.txt 112310
# shakespeare-hamlet.txt 162881
# shakespeare-macbeth.txt 100351
# whitman-leaves.txt 711215

# %%
# more advanced, for those with some Python experience, or those who want to google around..
# solution 2: make a list of titles and a list of wordcounts, zip them together, then sort them based on wordcount
# starter code:
import pandas as pd

books = nltk.corpus.gutenberg.fileids()

titles = []
numwords = []
for title in books:
    book = nltk.corpus.gutenberg.raw(title)
    titles.append(title)
    numwords.append(len(book))

df
# Out:
#                      titles  word count
# 0           austen-emma.txt      887071
# 1     austen-persuasion.txt      466292
# 2          austen-sense.txt      673022
# 3             bible-kjv.txt     4332554
# 4           blake-poems.txt       38153
# 5        bryant-stories.txt      249439
# 6   burgess-busterbrown.txt       84663
# 7         carroll-alice.txt      144395
# 8       chesterton-ball.txt      457450
# 9      chesterton-brown.txt      406629
# 10  chesterton-thursday.txt      320525
# 11    edgeworth-parents.txt      935158
# 12   melville-moby_dick.txt     1242990
# 13      milton-paradise.txt      468220
# 14   shakespeare-caesar.txt      112310
# 15   shakespeare-hamlet.txt      162881
# 16  shakespeare-macbeth.txt      100351
# 17       whitman-leaves.txt      711215

# %%
df = pd.DataFrame({'titles':titles, 'word count':numwords})
df.sort_values(by='word count', ascending=False)
# Out:
#                      titles  word count
# 3             bible-kjv.txt     4332554
# 12   melville-moby_dick.txt     1242990
# 11    edgeworth-parents.txt      935158
# 0           austen-emma.txt      887071
# 17       whitman-leaves.txt      711215
# 2          austen-sense.txt      673022
# 13      milton-paradise.txt      468220
# 1     austen-persuasion.txt      466292
# 8       chesterton-ball.txt      457450
# 9      chesterton-brown.txt      406629
# 10  chesterton-thursday.txt      320525
# 5        bryant-stories.txt      249439
# 15   shakespeare-hamlet.txt      162881
# 7         carroll-alice.txt      144395
# 14   shakespeare-caesar.txt      112310
# 16  shakespeare-macbeth.txt      100351
# 6   burgess-busterbrown.txt       84663
# 4           blake-poems.txt       38153

# %% [markdown]
# ## Challenge 3: what are the most frequent words?
#
# `nltk` has a built-in function called `FreqDist` which counts up how many times each word in a text occurs. So, if you have a list called `words` which contains all the words in a book, you can find the frequencies of all of them by writing `freq = nltk.FreqDist(words)`. You can then get the e.g. ten most common words by writing `freq.most_common(10)`. What are the ten most common words in Jane Austen's "Emma"? What about Herman Melville's "Moby Dick"?

# %%
# starter code:

book = nltk.corpus.gutenberg.raw('austen-emma.txt')
words = book.lower()
words = words.replace('\n', ' ')
words = words.split()

freq = nltk.FreqDist(words)
freq.most_common(10)
# Out:
# [('the', 5120),
#  ('to', 5079),
#  ('and', 4445),
#  ('of', 4196),
#  ('a', 3055),
#  ('i', 2602),
#  ('was', 2302),
#  ('she', 2169),
#  ('in', 2091),
#  ('not', 2028)]

# %%
book = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')
words = book.lower()
words = words.replace('\n', ' ')
words = words.split()

freq = nltk.FreqDist(words)
freq.most_common(10)
# Out:
# [('the', 14226),
#  ('of', 6545),
#  ('and', 6238),
#  ('a', 4597),
#  ('to', 4518),
#  ('in', 4058),
#  ('that', 2744),
#  ('his', 2485),
#  ('it', 1765),
#  ('i', 1724)]

# %% [markdown]
# ## Challenge 4: Remove stopwords
#
# Often, the most frequent words are not the most interesting ones. Words like "a" and "the" are so common in English, that they don't really tell us much about the text. That is why we often remove "stopwords", that is, a list of the most common words in English, before e.g. counting frequencies. There are several of these lists available, in [English]((https://gist.github.com/sebleier/554280)) as well as other languages, such as [Danish](https://gist.github.com/berteltorp/0cf8a0c7afea7f25ed754f24cfc2467b). Below is some starter code to remove stopwords. Use these snippets to see what the most common words in Emma and Moby Dick are after removing these most common words.
#
# Hint: In Moby Dick, you will also have to remove the string `\r`, in addition to removing `\n`.

# %%
# list of stopwords

stopwords = ["", "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
book = nltk.corpus.gutenberg.raw('austen-emma.txt')
words = book.lower()
words = words.replace('\n', ' ')
words = words.split()

# code to remove stopwords.
words = [word for word in words if word not in stopwords]
freq = nltk.FreqDist(words)
freq.most_common(10)
# Out:
# [('mr.', 1097),
#  ('could', 800),
#  ('would', 795),
#  ('mrs.', 675),
#  ('miss', 568),
#  ('must', 543),
#  ('emma', 481),
#  ('much', 427),
#  ('every', 425),
#  ('said', 392)]

# %%
book = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')
words = book.lower()
words = words.replace('\n', ' ')
words = words.replace('\r', ' ')
words = words.split()

# code to remove stopwords.
words = [word for word in words if word not in stopwords]
freq = nltk.FreqDist(words)
freq.most_common(10)
# Out:
# [('one', 779),
#  ('like', 564),
#  ('upon', 556),
#  ('whale', 528),
#  ('old', 425),
#  ('would', 416),
#  ('though', 311),
#  ('great', 292),
#  ('still', 282),
#  ('seemed', 273)]
